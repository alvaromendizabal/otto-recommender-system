# %% [markdown]
# # OTTO · Round 04 — saved results only
#
# No training, raw-data scan, feature construction or package installation. Each Plotly MIME display returns explicitly; charts represent saved experiment outputs, not a Kaggle score.

# %%
from pathlib import Path
import importlib.util
import json
import sys
ROOT = next((p for p in [Path.cwd(), *Path.cwd().parents]
             if (p / 'demand_features.py').is_file() and (p / 'launch.py').is_file()),
            Path.home() / 'otto_feature_round04')
if not (ROOT / 'demand_features.py').is_file():
    raise RuntimeError('Open this notebook from the extracted otto_feature_round04 folder')
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))
spec = importlib.util.spec_from_file_location('otto_round04_launcher', ROOT / 'launch.py')
launch = importlib.util.module_from_spec(spec)
spec.loader.exec_module(launch)
sys.modules['launch'] = launch
view_spec = importlib.util.spec_from_file_location('otto_round04_view', ROOT/'notebook_view.py')
view = importlib.util.module_from_spec(view_spec)
view_spec.loader.exec_module(view)
result = view.start()
# Out:
# KERNEL_READY — saved results only, no training. Notebook Python: /opt/conda/bin/python
# **Decision:** STOP_THIS_CONFIGURATION_NO_GAIN
#
# **Rolling-demand primary gain versus matched control:** -0.015208
#
# Reused fitting-cohort exploratory feature screen. Not a Kaggle score; no feature promotion.

# %% [markdown]
# ## Matched pooled scores

# %%
view.show_chart(1)
# Out:
# Round 04 chart 1 (interactive Plotly)
# CHART_1_PAYLOAD_SENT — Python display returned.

# %% [markdown]
# ## Paired descriptive uncertainty

# %%
view.show_chart(2)
# Out:
# Round 04 chart 2 (interactive Plotly)
# CHART_2_PAYLOAD_SENT — Python display returned.

# %% [markdown]
# ## Chronological-fold stability

# %%
view.show_chart(3)
# Out:
# Round 04 chart 3 (interactive Plotly)
# CHART_3_PAYLOAD_SENT — Python display returned.

# %% [markdown]
# ## Click/cart/order recall

# %%
view.show_chart(4)
# Out:
# Round 04 chart 4 (interactive Plotly)
# CHART_4_PAYLOAD_SENT — Python display returned.

# %% [markdown]
# ## Which extra hits move the score?

# %%
view.show_chart(5)
# Out:
# Round 04 chart 5 (interactive Plotly)
# CHART_5_PAYLOAD_SENT — Python display returned.

# %% [markdown]
# ## Training-only demand support

# %%
view.show_chart(6)
# Out:
# Round 04 chart 6 (interactive Plotly)
# CHART_6_PAYLOAD_SENT — Python display returned.

# %% [markdown]
# ## Training-only redundancy

# %%
view.show_chart(7)
# Out:
# Round 04 chart 7 (interactive Plotly)
# CHART_7_PAYLOAD_SENT — Python display returned.

# %% [markdown]
# ## Finish and collect the report

# %%
view.finish()
# Out:
# ROUND04_NOTEBOOK_REVIEW_COMPLETE
# RETURN_FILE: /home/sagemaker-user/otto_feature_round04/otto_round04_return.zip
# '/home/sagemaker-user/otto_feature_round04/otto_round04_return.zip'
