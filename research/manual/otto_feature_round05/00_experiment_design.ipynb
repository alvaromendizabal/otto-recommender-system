# %% [markdown]
# # OTTO · Round 05 — Preserve action meaning
#
# **Hypothesis:** independently counted historical “view A → cart B” relationships contain useful information that a pooled adjacent-item relation loses. This is a new feature screen, not a promised improvement.
#
# The first two figures replay actual Round04 results. The third depicts the proposed column counts, not measured performance.

# %%
from pathlib import Path
import json
import plotly.graph_objects as go
from IPython.display import display
ROOT=next((p for p in [Path.cwd(),*Path.cwd().parents] if (p/'evidence/ROUND04_RESULT.json').is_file()),Path.home()/'otto_feature_round05')
result=json.loads((ROOT/'evidence/ROUND04_RESULT.json').read_text())
def show(fig):
    fig.update_layout(height=440,margin=dict(l=70,r=35,t=80,b=80),font=dict(size=14))
    display({'application/vnd.plotly.v1+json':json.loads(fig.to_json())},raw=True)
print('DESIGN_READY — prior measured results and proposed schema only; zero experiment fits.')
# Out:
# DESIGN_READY — prior measured results and proposed schema only; zero experiment fits.

# %% [markdown]
# ## 1 · The demand hypothesis did not beat its control
# Both new demand configurations regress. Keep their evidence and expensive index, but do not refit or submit these configurations.

# %%
keys=['control_shared','demand_rolling','demand_static_ablation']
show(go.Figure(go.Bar(x=['134-feature control','+ rolling demand','+ fixed demand'],
    y=[result['arms'][k]['weighted_recall_at_20'] for k in keys],
    text=[f"{result['arms'][k]['weighted_recall_at_20']:.6f}" for k in keys],textposition='auto')).update_layout(
    title='Round 04 • actual fitting-data scores',yaxis_title='Pooled weighted Recall@20'))

# %% [markdown]
# ## 2 · Lost order hits dominated the primary decline
# Do not compare an individual internal fold with the Kaggle private leaderboard. These changes use the identical paired validation sessions.

# %%
base=result['arms']['control_shared']['hits'];rolling=result['arms']['demand_rolling']['hits']
show(go.Figure(go.Bar(x=['Clicks','Carts','Orders'],y=[r-b for r,b in zip(rolling,base)],
    text=[f'{r-b:+d}' for r,b in zip(rolling,base)],textposition='auto')).update_layout(
    title='Round 04 • rolling-minus-control hit counts',yaxis_title='Additional hits at 20'))

# %% [markdown]
# ## 3 · A different information source, not more timing variations
# The new primary preserves all nine historical source/destination action pairs and three statistics per pair. The ablation collapses historical action types before counting, with the same observed anchors. Its nine columns are an information-removal ablation, not a width-matched placebo.
#
# Relationships are exact adjacent original indices, different items, ≤30 minutes, and strictly before Aug16 22:00 UTC. Each session contributes at most one support unit per directed pair/type. Outgoing denominators include noncandidate destinations.

# %%
show(go.Figure(go.Bar(x=['Saved control','Control + typed transitions','Control + collapsed transitions'],
    y=[134,161,143],text=[134,161,143],textposition='auto')).update_layout(
    title='Round 05 • proposed representation sizes (not results)',yaxis_title='Feature columns'))
print('DESIGN_COMPLETE — no Round05 prediction result exists in this notebook.')
# Out:
# DESIGN_COMPLETE — no Round05 prediction result exists in this notebook.

# %% [markdown]
# ## Research and decision
# Sixth/seventh-place OTTO accounts describe action-pair-conditioned covisitation. They motivate this representation class, not the exact 27 formulas. See RESEARCH_PLAN.md for primary sources and all limitations.
#
# Primary gain ≥.003, both chronological fold changes nonnegative, and no pooled order loss permits a separate different-cohort/different-window confirmation proposal only. Reusing this fitting cohort makes all comparisons exploratory. The 0.60503 private target remains unmet.
#
# Start with `01_build_transition_index.ipynb`; no new kernel, raw download, graph rebuild, or environment installation.
