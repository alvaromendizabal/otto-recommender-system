# %% [markdown]
# # OTTO · Round 05 — Saved results
#
# This notebook **never** builds an index, generates features or fits models. Read measured results after the execution notebook succeeds. All intervals are descriptive for reused fitting data; no automatic promotion.

# %%
from pathlib import Path
import importlib.util, sys
ROOT = next((p for p in [Path.cwd(), *Path.cwd().parents]
             if (p/'notebook_view.py').is_file() and (p/'transition_features.py').is_file()),
            Path.home()/'otto_feature_round05')
sys.path.insert(0,str(ROOT))
spec=importlib.util.spec_from_file_location('otto_round05_saved_view',ROOT/'notebook_view.py')
view=importlib.util.module_from_spec(spec)
spec.loader.exec_module(view)
result=view.start()
# Out:
# KERNEL_READY — saved results only, no training. Notebook Python: /opt/conda/bin/python
# **Decision:** STOP_THIS_CONFIGURATION_NO_GAIN
#
# **Action-pair primary gain versus matched control:** -0.012804
#
# Reused fitting-cohort exploratory feature screen. Not a Kaggle score; no feature promotion.

# %% [markdown]
# ## 1 · Matched pooled score

# %%
view.show_chart(1)
# Out:
# Round 05 chart 1 (interactive Plotly)
# CHART_1_PAYLOAD_SENT — Python display returned.

# %% [markdown]
# ## 2 · Paired uncertainty

# %%
view.show_chart(2)
# Out:
# Round 05 chart 2 (interactive Plotly)
# CHART_2_PAYLOAD_SENT — Python display returned.

# %% [markdown]
# ## 3 · Chronological-fold changes

# %%
view.show_chart(3)
# Out:
# Round 05 chart 3 (interactive Plotly)
# CHART_3_PAYLOAD_SENT — Python display returned.

# %% [markdown]
# ## 4 · Clicks, carts and orders

# %%
view.show_chart(4)
# Out:
# Round 05 chart 4 (interactive Plotly)
# CHART_4_PAYLOAD_SENT — Python display returned.

# %% [markdown]
# ## 5 · Additional hits and their metric contribution

# %%
view.show_chart(5)
# Out:
# Round 05 chart 5 (interactive Plotly)
# CHART_5_PAYLOAD_SENT — Python display returned.

# %% [markdown]
# ## 6 · Training-only feature support

# %%
view.show_chart(6)
# Out:
# Round 05 chart 6 (interactive Plotly)
# CHART_6_PAYLOAD_SENT — Python display returned.

# %% [markdown]
# ## 7 · Training-only redundancy

# %%
view.show_chart(7)
# Out:
# Round 05 chart 7 (interactive Plotly)
# CHART_7_PAYLOAD_SENT — Python display returned.

# %% [markdown]
# ## Save and return
# After this marker, save the notebook and run the terminal `bundle` command once. This includes the saved execution numbers in the ZIP.

# %%
view.finish()
# Out:
# ROUND05_NOTEBOOK_REVIEW_COMPLETE
# RETURN_FILE: /home/sagemaker-user/otto_feature_round05/otto_round05_return.zip
# '/home/sagemaker-user/otto_feature_round05/otto_round05_return.zip'
