# %% [markdown]
# # OTTO · Round 02 — saved results
#
# **Review only: zero model fits or feature reconstruction.** Explicit Plotly MIME display is used throughout. A Python completion marker confirms each display call returned; the receipt does not claim to inspect your browser pixels.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd()
if not (ROOT / 'notebook_view.py').is_file():
    raise RuntimeError('Open this notebook in otto_feature_round02.')
import notebook_view
result = notebook_view.start()
# Out:
# KERNEL_READY — saved results only, no training. Notebook Python: /opt/conda/bin/python
# **Decision:** DO_NOT_RETAIN_NO_REPLICATION_GAIN
#
# **Timing minus matched control:** -0.002806
#
# Fitting-only temporal replication. Not a Kaggle score; no feature promotion.

# %% [markdown]
# ## Matched model scores

# %%
notebook_view.show_chart(1)
# Out:
# Round 02 chart 1 (interactive Plotly)
# CHART_1_PAYLOAD_SENT — Python display returned.

# %% [markdown]
# ## Paired descriptive uncertainty

# %%
notebook_view.show_chart(2)
# Out:
# Round 02 chart 2 (interactive Plotly)
# CHART_2_PAYLOAD_SENT — Python display returned.

# %% [markdown]
# ## Chronological stability

# %%
notebook_view.show_chart(3)
# Out:
# Round 02 chart 3 (interactive Plotly)
# CHART_3_PAYLOAD_SENT — Python display returned.

# %% [markdown]
# ## Click/cart/order performance

# %%
notebook_view.show_chart(4)
# Out:
# Round 02 chart 4 (interactive Plotly)
# CHART_4_PAYLOAD_SENT — Python display returned.

# %% [markdown]
# ## Which hits explain the difference?

# %%
notebook_view.show_chart(5)
# Out:
# Round 02 chart 5 (interactive Plotly)
# CHART_5_PAYLOAD_SENT — Python display returned.

# %% [markdown]
# ## Training-only timing availability

# %%
notebook_view.show_chart(6)
# Out:
# Round 02 chart 6 (interactive Plotly)
# CHART_6_PAYLOAD_SENT — Python display returned.

# %% [markdown]
# ## Training-only redundancy

# %%
notebook_view.show_chart(7)
# Out:
# Round 02 chart 7 (interactive Plotly)
# CHART_7_PAYLOAD_SENT — Python display returned.

# %% [markdown]
# ## Save evidence and stop unused compute
# Save the notebook, download `otto_round02_return.zip`, and return it to ChatGPT. Stop **the application** in Studio → Running instances → otto-dev/JupyterLab → Stop. Do not delete the space. To include the latest saved notebook bytes, use `launch.collect()` after saving.

# %%
notebook_view.finish()
# Out:
# ROUND02_NOTEBOOK_REVIEW_COMPLETE
# RETURN_FILE: /home/sagemaker-user/otto_feature_round02/otto_round02_return.zip
# '/home/sagemaker-user/otto_feature_round02/otto_round02_return.zip'
