# %% [markdown]
# # Round 12 | Saved results
#
# Read-only visualization. Run All is safe here after report completion; no features, representations, or models are rebuilt. Save to retain inline Plotly output.

# %%
from pathlib import Path
import json, sys, importlib.util
ROOT = Path.home() / "otto_feature_round12"
assert ROOT.is_dir(), ROOT
if str(ROOT) not in sys.path: sys.path.insert(0, str(ROOT))
spec = importlib.util.spec_from_file_location("otto_launcher_12", ROOT / "launch.py")
launcher = importlib.util.module_from_spec(spec)
spec.loader.exec_module(launcher)
def stage(name):
    return launcher.run_stage(name)
def require(relative, key, expected):
    value = json.loads((ROOT / relative).read_text())
    assert value[key] == expected, (relative, value.get(key))
    print(expected)
    return value
print("KERNEL_READY")
receipt = require("outputs/report_receipt.json", "status", "ROUND12_REPORT_READY")
import hashlib
import plotly.io as pio
pio.renderers.default = "notebook_connected+plotly_mimetype"
plots = sorted(receipt["plot_hashes"])
assert len(plots) == 9

# %% [markdown]
# ## Result panel 1

# %%
relative = plots[0]
path = ROOT / "outputs/plots" / relative
assert hashlib.sha256(path.read_bytes()).hexdigest() == receipt["plot_hashes"][relative]
fig = pio.from_json(path.read_text())
fig.show()

# %% [markdown]
# ## Result panel 2

# %%
relative = plots[1]
path = ROOT / "outputs/plots" / relative
assert hashlib.sha256(path.read_bytes()).hexdigest() == receipt["plot_hashes"][relative]
fig = pio.from_json(path.read_text())
fig.show()

# %% [markdown]
# ## Result panel 3

# %%
relative = plots[2]
path = ROOT / "outputs/plots" / relative
assert hashlib.sha256(path.read_bytes()).hexdigest() == receipt["plot_hashes"][relative]
fig = pio.from_json(path.read_text())
fig.show()

# %% [markdown]
# ## Result panel 4

# %%
relative = plots[3]
path = ROOT / "outputs/plots" / relative
assert hashlib.sha256(path.read_bytes()).hexdigest() == receipt["plot_hashes"][relative]
fig = pio.from_json(path.read_text())
fig.show()

# %% [markdown]
# ## Result panel 5

# %%
relative = plots[4]
path = ROOT / "outputs/plots" / relative
assert hashlib.sha256(path.read_bytes()).hexdigest() == receipt["plot_hashes"][relative]
fig = pio.from_json(path.read_text())
fig.show()

# %% [markdown]
# ## Result panel 6

# %%
relative = plots[5]
path = ROOT / "outputs/plots" / relative
assert hashlib.sha256(path.read_bytes()).hexdigest() == receipt["plot_hashes"][relative]
fig = pio.from_json(path.read_text())
fig.show()

# %% [markdown]
# ## Result panel 7

# %%
relative = plots[6]
path = ROOT / "outputs/plots" / relative
assert hashlib.sha256(path.read_bytes()).hexdigest() == receipt["plot_hashes"][relative]
fig = pio.from_json(path.read_text())
fig.show()

# %% [markdown]
# ## Result panel 8

# %%
relative = plots[7]
path = ROOT / "outputs/plots" / relative
assert hashlib.sha256(path.read_bytes()).hexdigest() == receipt["plot_hashes"][relative]
fig = pio.from_json(path.read_text())
fig.show()

# %% [markdown]
# ## Result panel 9

# %%
relative = plots[8]
path = ROOT / "outputs/plots" / relative
assert hashlib.sha256(path.read_bytes()).hexdigest() == receipt["plot_hashes"][relative]
fig = pio.from_json(path.read_text())
fig.show()

# %% [markdown]
# Save all notebooks with Ctrl+S. Then run the report-only `launch.py bundle` command in a terminal so saved execution outputs are included. A notebook cannot guarantee it has saved its own latest cells before bundling.
