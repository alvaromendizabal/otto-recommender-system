# %% [markdown]
# # Round 12 | Directed action-context latent affinities
#
# Prepared, unexecuted notebook. Review the actual uploaded R09/R10 evidence first. The four challenger point estimates were below the saved control; all descriptive intervals cross zero. Keep the control. Do not rerun completed R09/R10.

# %%
from pathlib import Path
import json
import plotly.graph_objects as go
import plotly.io as pio
pio.renderers.default = "notebook_connected+plotly_mimetype"
ROOT = Path.home() / "otto_feature_round12"
figures = json.loads((ROOT / "review/figures.json").read_text())
print("Uploaded R09/R10 results only; not new Round 11/12 scores.")

# %% [markdown]
# ## Evidence panel 1
# Read the evaluation setting in the title; these are exploratory fitting-fold results, not a leaderboard comparison.

# %%
fig = go.Figure(figures[0])
fig.show()

# %% [markdown]
# ## Evidence panel 2
# Read the evaluation setting in the title; these are exploratory fitting-fold results, not a leaderboard comparison.

# %%
fig = go.Figure(figures[1])
fig.show()

# %% [markdown]
# ## Evidence panel 3
# Read the evaluation setting in the title; these are exploratory fitting-fold results, not a leaderboard comparison.

# %%
fig = go.Figure(figures[2])
fig.show()

# %% [markdown]
# ## Evidence panel 4
# Read the evaluation setting in the title; these are exploratory fitting-fold results, not a leaderboard comparison.

# %%
fig = go.Figure(figures[3])
fig.show()

# %% [markdown]
# ## Evidence panel 5
# Read the evaluation setting in the title; these are exploratory fitting-fold results, not a leaderboard comparison.

# %%
fig = go.Figure(figures[4])
fig.show()

# %% [markdown]
# ## Evidence panel 6
# Read the evaluation setting in the title; these are exploratory fitting-fold results, not a leaderboard comparison.

# %%
fig = go.Figure(figures[5])
fig.show()

# %% [markdown]
# ## Next hypothesis
#
# ## Hypothesis and novelty
#
# Direct event-count features can miss products related through similar historical context. A low-rank directed product/action association representation may generalize across sparse direct edges. This round changes the representation from the Round09 local-neighbor continuation counts to a learned action-specific context basis over the certified cached history. It does not add Round11's features or inherit a winning configuration from Round11.
#
# The primary preserves forward event direction. The width-matched ablation removes direction while keeping the same vocabulary, time/position limits, three destination-action types, aggregation functions and ranker. A completed negative Round11 does not block this predeclared hypothesis; an operational failure does.
#
#
# Full formulas and limits: RESEARCH_PLAN.md. No new test or experiment result is claimed before you run it.
