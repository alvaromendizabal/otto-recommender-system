# %% [markdown]
# # OTTO Round 08 · Saved results
# ## Rarity-weighted historical-session evidence
#
# This notebook reads nine saved Plotly payloads; it does not train or extract data. Run All is safe **only after** the report stage succeeded. Save all notebooks, then execute the final bundle command in the terminal to include saved execution outputs.

# %%
from pathlib import Path
import importlib.util, json
ROOT=Path.home()/'otto_feature_round08'
spec=importlib.util.spec_from_file_location('otto_round08_launcher',ROOT/'launch.py')
launcher=importlib.util.module_from_spec(spec);spec.loader.exec_module(launcher)
def stage(name):
    return launcher.run_stage(name)
def require(path,status):
    row=json.loads(Path(path).read_text())
    if row.get('status')!=status:raise RuntimeError('STOPPED_REVIEW_REQUIRED: missing completed stage '+status)
    print(status)
    return row
print('KERNEL_READY')
receipt=require(ROOT/'outputs/report_receipt.json','ROUND08_REPORT_READY')
import hashlib
from IPython.display import display
# Out:
# KERNEL_READY
# ROUND08_REPORT_READY

# %% [markdown]
# ## 1 · Matched weighted Recall@20

# %%
path=ROOT/'outputs/plots/01.json'
if hashlib.sha256(path.read_bytes()).hexdigest()!=receipt['plot_hashes'][path.name]:raise ValueError('Plot checksum changed')
display({'application/vnd.plotly.v1+json':json.loads(path.read_text())},raw=True)

# %% [markdown]
# ## 2 · Paired descriptive intervals

# %%
path=ROOT/'outputs/plots/02.json'
if hashlib.sha256(path.read_bytes()).hexdigest()!=receipt['plot_hashes'][path.name]:raise ValueError('Plot checksum changed')
display({'application/vnd.plotly.v1+json':json.loads(path.read_text())},raw=True)

# %% [markdown]
# ## 3 · Fold stability

# %%
path=ROOT/'outputs/plots/03.json'
if hashlib.sha256(path.read_bytes()).hexdigest()!=receipt['plot_hashes'][path.name]:raise ValueError('Plot checksum changed')
display({'application/vnd.plotly.v1+json':json.loads(path.read_text())},raw=True)

# %% [markdown]
# ## 4 · Action recall

# %%
path=ROOT/'outputs/plots/04.json'
if hashlib.sha256(path.read_bytes()).hexdigest()!=receipt['plot_hashes'][path.name]:raise ValueError('Plot checksum changed')
display({'application/vnd.plotly.v1+json':json.loads(path.read_text())},raw=True)

# %% [markdown]
# ## 5 · Exact target-hit contributions

# %%
path=ROOT/'outputs/plots/05.json'
if hashlib.sha256(path.read_bytes()).hexdigest()!=receipt['plot_hashes'][path.name]:raise ValueError('Plot checksum changed')
display({'application/vnd.plotly.v1+json':json.loads(path.read_text())},raw=True)

# %% [markdown]
# ## 6 · Representation contrast

# %%
path=ROOT/'outputs/plots/06.json'
if hashlib.sha256(path.read_bytes()).hexdigest()!=receipt['plot_hashes'][path.name]:raise ValueError('Plot checksum changed')
display({'application/vnd.plotly.v1+json':json.loads(path.read_text())},raw=True)

# %% [markdown]
# ## 7 · Training-only redundancy

# %%
path=ROOT/'outputs/plots/07.json'
if hashlib.sha256(path.read_bytes()).hexdigest()!=receipt['plot_hashes'][path.name]:raise ValueError('Plot checksum changed')
display({'application/vnd.plotly.v1+json':json.loads(path.read_text())},raw=True)

# %% [markdown]
# ## 8 · Candidate ceiling versus achieved ranking

# %%
path=ROOT/'outputs/plots/08.json'
if hashlib.sha256(path.read_bytes()).hexdigest()!=receipt['plot_hashes'][path.name]:raise ValueError('Plot checksum changed')
display({'application/vnd.plotly.v1+json':json.loads(path.read_text())},raw=True)

# %% [markdown]
# ## 9 · Training-positive support

# %%
path=ROOT/'outputs/plots/09.json'
if hashlib.sha256(path.read_bytes()).hexdigest()!=receipt['plot_hashes'][path.name]:raise ValueError('Plot checksum changed')
display({'application/vnd.plotly.v1+json':json.loads(path.read_text())},raw=True)

# %%
print('ROUND08_RESULTS_DISPLAYED: save notebooks; run launch.py bundle in the terminal')
# Out:
# ROUND08_RESULTS_DISPLAYED: save notebooks; run launch.py bundle in the terminal
