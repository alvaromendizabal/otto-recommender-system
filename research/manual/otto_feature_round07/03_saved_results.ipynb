# %% [markdown]
# # Round 07 / Saved results
# **No feature building or model training occurs here.** After a successful audit, Run All is appropriate for this notebook. Save all notebooks before running the final bundle command in the terminal. The HTML report is at `outputs/round07_report.html`.

# %%
from pathlib import Path
import sys
ROOT=Path.home()/"otto_feature_round07"
sys.path.insert(0,str(ROOT))
import notebook_view as view
view.start()
# Out:
# KERNEL_READY — saved results only, no training. Notebook Python: /opt/conda/bin/python
# **Decision:** REVIEW_FOR_MATCHED_RANKER_SCREEN_NOT_PROMOTION
#
# **Zero new model fits.** Training-only feature support and candidate-oracle audit; not achieved ranker accuracy or a Kaggle score.
# {'achieved_ranker_score': None,
#  'arms': {'last_anchor': {'expanded_candidate_oracle': {'denominators': [236,
#      70,
#      33],
#     'hits': [164, 38, 18],
#     'recall': {'carts': 0.5428571428571428,
#      'clicks': 0.6949152542372882,
#      'orders': 0.5454545454545454},
#     'weighted_oracle_at20': 0.5596213955535989},
#    'mean_new_candidates_by_objective': [60.1015625, 35.23046875, 14.94921875],
#    'net_capped_hits': [6, 1, 0],
#    'new_distinct_target_hits': [6, 1, 0],
#    'supported_baseline_positive_items': [137, 27, 12]},
#   'session_context': {'expanded_candidate_oracle': {'denominators': [236,
#      70,
#      33],
#     'hits': [164, 38, 18],
# ...

# %% [markdown]
# ## Chart 1

# %%
view.show_chart(1)
# Out:
# Round 07 chart 1 (interactive Plotly)
# CHART_1_PAYLOAD_SENT — Python display returned.

# %% [markdown]
# ## Chart 2

# %%
view.show_chart(2)
# Out:
# Round 07 chart 2 (interactive Plotly)
# CHART_2_PAYLOAD_SENT — Python display returned.

# %% [markdown]
# ## Chart 3

# %%
view.show_chart(3)
# Out:
# Round 07 chart 3 (interactive Plotly)
# CHART_3_PAYLOAD_SENT — Python display returned.

# %% [markdown]
# ## Chart 4

# %%
view.show_chart(4)
# Out:
# Round 07 chart 4 (interactive Plotly)
# CHART_4_PAYLOAD_SENT — Python display returned.

# %% [markdown]
# ## Chart 5

# %%
view.show_chart(5)
# Out:
# Round 07 chart 5 (interactive Plotly)
# CHART_5_PAYLOAD_SENT — Python display returned.

# %% [markdown]
# ## Chart 6

# %%
view.show_chart(6)
# Out:
# Round 07 chart 6 (interactive Plotly)
# CHART_6_PAYLOAD_SENT — Python display returned.

# %% [markdown]
# ## Chart 7

# %%
view.show_chart(7)
# Out:
# Round 07 chart 7 (interactive Plotly)
# CHART_7_PAYLOAD_SENT — Python display returned.

# %% [markdown]
# ## Chart 8

# %%
view.show_chart(8)
# Out:
# Round 07 chart 8 (interactive Plotly)
# CHART_8_PAYLOAD_SENT — Python display returned.

# %% [markdown]
# ## Package the saved evidence

# %%
view.finish()
# Out:
# ROUND07_NOTEBOOK_REVIEW_COMPLETE
# RETURN_FILE: /home/sagemaker-user/otto_feature_round07/otto_round07_return.zip
# CompletedProcess(args=['/opt/conda/bin/python', '-u', '/home/sagemaker-user/otto_feature_round07/launch.py', 'bundle'], returncode=0)
