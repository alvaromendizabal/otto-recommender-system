# %% [markdown]
# # OTTO / Round 06
# ## Verified result and the next research decision
#
# **Keep the 134-feature control. Do not rerun Round 06.** Both candidate-relative additions lost on both folds; neither earned retention. Their descriptive paired intervals include zero, so do not claim a conclusive population-level harm. These are reused fitting-cohort measurements, not a Kaggle score.
#
# The next investigation adds historical-session evidence, rather than re-expressing the same graph affinities. A fixed training-only feasibility pilot comes before further ranker fitting.

# %%
import json
import numpy as np
import plotly.graph_objects as go
from IPython.display import display
RESULT=json.loads('{"added_features": 12, "algorithm_search": false, "arms": {"control_shared": {"denominators": [1979, 574, 325], "hits": [989, 227, 217], "recall": {"carts": 0.39547038327526135, "clicks": 0.4997473471450227, "orders": 0.6676923076923077}, "weighted_recall_at_20": 0.5692312343124653}, "global_context_ablation": {"denominators": [1979, 574, 325], "hits": [969, 218, 216], "recall": {"carts": 0.3797909407665505, "clicks": 0.4896412329459323, "orders": 0.6646153846153846}, "weighted_recall_at_20": 0.5616706362937891}, "repeat_context": {"denominators": [1979, 574, 325], "hits": [957, 213, 216], "recall": {"carts": 0.3710801393728223, "clicks": 0.48357756442647803, "orders": 0.6646153846153846}, "weighted_recall_at_20": 0.5584510290237252}}, "candidate_context_before_label_dependent_sampling": true, "candidate_coverage_sha256": "f28477a7c74f530d98a7e2b3e3f927e21075f4ea0a591b655be411e67730df38", "comparisons": {"global_context_ablation_minus_control_shared": {"decision": "STOP_THIS_CONFIGURATION_NO_GAIN", "descriptive_95_interval": [-0.02010374176499464, 0.004778349592051018], "fold_gains": [-0.010016286251956275, -0.005000443105281804], "gain": -0.007560598018676146, "method": "paired session bootstrap within time fold; descriptive", "net_extra_hits": {"carts": -9, "clicks": -20, "orders": -1}, "no_automatic_promotion": true, "one_order_hit_weight": 0.0018461538461538461, "order_gain": -0.003076923076923088, "replicates": 2000, "weighted_contributions": {"carts": -0.00470383275261324, "clicks": -0.001010611419909045, "orders": -0.0018461538461538461}}, "repeat_context_minus_control_shared": {"decision": "STOP_THIS_CONFIGURATION_NO_GAIN", "descriptive_95_interval": [-0.025262745432023323, 0.0031227306195693513], "fold_gains": [-0.015708894814431273, -0.005504475363346306], "gain": -0.010780205288740019, "method": "paired session bootstrap within time fold; descriptive", "net_extra_hits": {"carts": -14, "clicks": -32, "orders": -1}, "no_automatic_promotion": true, "one_order_hit_weight": 0.0018461538461538461, "order_gain": -0.003076923076923088, "replicates": 2000, "weighted_contributions": {"carts": -0.007317073170731707, "clicks": -0.0016169782718544721, "orders": -0.0018461538461538461}}, "repeat_context_minus_global_context_ablation": {"decision": "STOP_THIS_CONFIGURATION_NO_GAIN", "descriptive_95_interval": [-0.01455429134751242, 0.008586044454844123], "fold_gains": [-0.005692608562474999, -0.0005040322580645018], "gain": -0.0032196072700638734, "method": "paired session bootstrap within time fold; descriptive", "net_extra_hits": {"carts": -5, "clicks": -12, "orders": 0}, "no_automatic_promotion": true, "one_order_hit_weight": 0.0018461538461538461, "order_gain": 0.0, "replicates": 2000, "weighted_contributions": {"carts": -0.0026132404181184667, "clicks": -0.0006063668519454271, "orders": 0.0}}}, "competition_test_access": false, "context_diagnostics_sha256": "68e253af2fa7c622c88e4b55e7062bd9e063c679f0977f0512c696ccdd83504b", "control_features": 134, "control_models_refit": 0, "control_prediction_replay_exact": true, "control_recipe_unchanged": true, "evaluation_access": false, "feature_engineering_complete": false, "feature_retention_decisions": 0, "fold_results": [{"arm": "control_shared", "denominators": [987, 301, 166], "features": 134, "fold": 0, "hits": [494, 113, 104], "recall": {"carts": 0.3754152823920266, "clicks": 0.5005065856129686, "orders": 0.6265060240963856}, "weighted_recall_at_20": 0.5385788577367362}, {"arm": "control_shared", "denominators": [992, 273, 159], "features": 134, "fold": 1, "hits": [495, 114, 113], "recall": {"carts": 0.4175824175824176, "clicks": 0.49899193548387094, "orders": 0.710691823899371}, "weighted_recall_at_20": 0.6015890131627349}, {"arm": "repeat_context", "denominators": [987, 301, 166], "features": 146, "fold": 0, "hits": [473, 103, 103], "recall": {"carts": 0.34219269102990035, "clicks": 0.47922998986828774, "orders": 0.6204819277108434}, "weighted_recall_at_20": 0.5228699629223049}, {"arm": "global_context_ablation", "denominators": [987, 301, 166], "features": 146, "fold": 0, "hits": [480, 108, 103], "recall": {"carts": 0.3588039867109635, "clicks": 0.48632218844984804, "orders": 0.6204819277108434}, "weighted_recall_at_20": 0.5285625714847799}, {"arm": "repeat_context", "denominators": [992, 273, 159], "features": 146, "fold": 1, "hits": [484, 110, 113], "recall": {"carts": 0.40293040293040294, "clicks": 0.4879032258064516, "orders": 0.710691823899371}, "weighted_recall_at_20": 0.5960845377993886}, {"arm": "global_context_ablation", "denominators": [992, 273, 159], "features": 146, "fold": 1, "hits": [489, 110, 113], "recall": {"carts": 0.40293040293040294, "clicks": 0.49294354838709675, "orders": 0.710691823899371}, "weighted_recall_at_20": 0.5965885700574531}], "historical_source_cutoff_ms": 1660687200000, "limitations": ["Reused Round02 fitting cohort; exploratory, not untouched confirmation.", "Six cached graph-affinity inputs with complete-prefix repeat status; no failed demand or transition additions retained.", "The source window is unchanged. Relative context does not fix source staleness or missing candidates.", "Both challengers add 12 columns. Global ablation removes repeat-stratum conditioning, not all candidate context.", "Conditional support uses censored training targets only; no automatic feature filtering.", "Candidate policy and model capacity held fixed; neither is proved optimal.", "No new Kaggle predictions, submission, leaderboard score or feature promotion."], "model_count": 12, "model_inventory": {"models/fold-0/global_context_ablation/carts/model.txt": "88e08c93508c8e1b583f80513201cc20f98dcccddb767134e5113dcad935c3ea", "models/fold-0/global_context_ablation/clicks/model.txt": "8e00c7ea127c6a929a542d561a777dfa9537f8c03149b98ddcfd94ab737826ff", "models/fold-0/global_context_ablation/orders/model.txt": "6327e83402b3240b50812619d8f29fcd0dd873449c75968c4b72b87bff5ef6b3", "models/fold-0/repeat_context/carts/model.txt": "02d1f436a232c5f3148e4b5fae4348b603e3e4c64c131ed8c17eb74f51011569", "models/fold-0/repeat_context/clicks/model.txt": "e81f273401f5e9192a75774b07e0233d4ee4149646d73fba55d31f943720d5f5", "models/fold-0/repeat_context/orders/model.txt": "15ae57ecf83304083d5c9924aad55fbaf80f08a5f92a3e56f9e420192bf7a1bb", "models/fold-1/global_context_ablation/carts/model.txt": "b6b32ee34200b46d5cdb017e8ddc549f6a434711313fa04ba17a28565e74e8ff", "models/fold-1/global_context_ablation/clicks/model.txt": "1e8c443006f56e8e60606964486efefc85159f612a8b9495d78527882c0a6247", "models/fold-1/global_context_ablation/orders/model.txt": "56a717032d4bd39515da91c672875bd1495f1d6c5a7f310e2d53358dce44d811", "models/fold-1/repeat_context/carts/model.txt": "42125be56744fa46f237ce77f0617db436d1b5842d5ce73e43f109b05f94db32", "models/fold-1/repeat_context/clicks/model.txt": "5f2ea86d5b2d295504c6fcff144b80ab3e7e79a45fb2a50f51fa8595d83f519d", "models/fold-1/repeat_context/orders/model.txt": "0cfcdbb3501400a918a167bb1ff1fe5284aec967776723e8a64709fcc4ca0d18"}, "native_reload_prediction_parity": true, "new_indices": 0, "old_graphs_rebuilt": 0, "original_graph_rebuilds": 0, "positive_support_sha256": "31ff9b63bc3eecea8a38ba87cbce1e1bcc1c68346054d4e45cfea672983e8d48", "primary_comparison": "repeat_context_minus_control_shared", "round02_timing_included": false, "round03_mass_included": false, "secondary_comparisons_are_not_advancement_gates": true, "selection_access": false, "sessions": 4096, "source_commit": "2638faa34afa427ed4ac4e92bba04deda57c688e", "statistics_sha256": "3eb3aea5c714befbdd66b9b0c10f2eb2fe2023254815869753b3279b3571d1ae", "status": "ROUND06_SCREEN_COMPLETED", "validation_sessions": 2048}')
COVERAGE=json.loads('{"exploratory_reused_fitting_cohort": true, "folds": [{"achieved_control": {"denominators": [987, 301, 166], "hits": [494, 113, 104], "recall": {"carts": 0.3754152823920266, "clicks": 0.5005065856129686, "orders": 0.6265060240963856}, "weighted_recall_at_20": 0.5385788577367362}, "candidate_oracle_at20": {"denominators": [987, 301, 166], "hits": [644, 171, 129], "recall": {"carts": 0.5681063122923588, "clicks": 0.6524822695035462, "orders": 0.7771084337349398}, "weighted_recall_at_20": 0.701945180879026}, "causal_attribution": false, "fold": 0, "metric_capped_not_uncapped_recall400": true, "new_model_fits": 0, "weighted_missing_candidate_gap": 0.298054819120974, "weighted_within_candidate_ranking_gap": 0.16336632314228983}, {"achieved_control": {"denominators": [992, 273, 159], "hits": [495, 114, 113], "recall": {"carts": 0.4175824175824176, "clicks": 0.49899193548387094, "orders": 0.710691823899371}, "weighted_recall_at_20": 0.6015890131627349}, "candidate_oracle_at20": {"denominators": [992, 273, 159], "hits": [644, 161, 129], "recall": {"carts": 0.5897435897435898, "clicks": 0.6491935483870968, "orders": 0.8113207547169812}, "weighted_recall_at_20": 0.7286348845919753}, "causal_attribution": false, "fold": 1, "metric_capped_not_uncapped_recall400": true, "new_model_fits": 0, "weighted_missing_candidate_gap": 0.27136511540802466, "weighted_within_candidate_ranking_gap": 0.1270458714292404}], "pooled": {"achieved_control": {"denominators": [1979, 574, 325], "hits": [989, 227, 217], "recall": {"carts": 0.39547038327526135, "clicks": 0.4997473471450227, "orders": 0.6676923076923077}, "weighted_recall_at_20": 0.5692312343124653}, "candidate_oracle_at20": {"denominators": [1979, 574, 325], "hits": [1288, 332, 258], "recall": {"carts": 0.578397212543554, "clicks": 0.650833754421425, "orders": 0.7938461538461539}, "weighted_recall_at_20": 0.714910231512901}, "causal_attribution": false, "metric_capped_not_uncapped_recall400": true, "new_model_fits": 0, "weighted_missing_candidate_gap": 0.285089768487099, "weighted_within_candidate_ranking_gap": 0.14567899720043576}, "untouched_holdout": false}')
CONTEXT=json.loads('[{"all_seen_queries": 0, "all_unseen_queries": 0, "fold": 0, "labels_used_to_define_strata": false, "mean_abs_primary_minus_global": [0.00027287271223030984, 0.0007327027851715684, 0.001088108983822167, 0.0008964290609583259, 0.001881481846794486, 0.0009616872412152588, 0.0016961023211479187, 0.0009495745180174708, 0.0002841916575562209, 0.0002427180006634444, 0.0003641189250629395, 0.0008176429546438158], "mean_seen_candidates": 2.7524271844660193, "strata": {"discovery": {"candidate_rows": 654664, "censored_positive_counts": {"carts": 120, "clicks": 519, "orders": 30}}, "repeat": {"candidate_rows": 4536, "censored_positive_counts": {"carts": 149, "clicks": 465, "orders": 158}}}, "training_only": true, "training_sessions": 1648}, {"all_seen_queries": 0, "all_unseen_queries": 0, "fold": 1, "labels_used_to_define_strata": false, "mean_abs_primary_minus_global": [0.0002634509583003819, 0.0007361700409092009, 0.0010710774222388864, 0.000898904399946332, 0.0018733922624960542, 0.0009631310822442174, 0.0016798835713416338, 0.0009500200394541025, 0.00030566396890208125, 0.00024392284103669226, 0.00035302090691402555, 0.0008180293370969594], "mean_seen_candidates": 2.7978161324410005, "strata": {"discovery": {"candidate_rows": 1127657, "censored_positive_counts": {"carts": 220, "clicks": 899, "orders": 57}}, "repeat": {"candidate_rows": 7943, "censored_positive_counts": {"carts": 262, "clicks": 852, "orders": 306}}}, "training_only": true, "training_sessions": 2839}]')
AUDIT=json.loads('{"archive_sha256": "a050905ae1f60a5f07ab8d998fa7ca8c6c1d3e8849dde987d5ba57199da1532f", "checksum_files_verified": 158, "independently_recalculated_scores": {"control_shared": 0.5692312343124653, "global_context_ablation": 0.5616706362937891, "repeat_context": 0.5584510290237252}, "independently_recalculated_intervals": {"global_context_ablation_minus_control_shared": [-0.02010374176499464, 0.004778349592051018], "repeat_context_minus_control_shared": [-0.025262745432023323, 0.0031227306195693513], "repeat_context_minus_global_context_ablation": [-0.01455429134751242, 0.008586044454844123]}, "six_fold_scores_reproduced": true, "previous_control_cohort_and_denominators_identical": true, "oracle_aggregate_arithmetic_verified": true, "oracle_candidate_membership_replayed": false, "notebooks": {"03_saved_results.ipynb": {"code_cells": 11, "executed_cells": 0, "errors": [], "plotly_payloads": 0}, "01_build_context_features.ipynb": {"code_cells": 4, "executed_cells": 4, "errors": [], "plotly_payloads": 0}, "00_review_and_design.ipynb": {"code_cells": 8, "executed_cells": 8, "errors": [], "plotly_payloads": 6}, "02_run_context_comparison.ipynb": {"code_cells": 5, "executed_cells": 5, "errors": [], "plotly_payloads": 0}}, "large_native_models_feature_matrices_and_history_absent": true, "new_cloud_jobs": 0, "decision": "Do not rerun Round06. Keep 134-feature control. Build new historical-session evidence with training-only support/retrieval audit before fitting."}')
def emit(fig):
    fig.update_layout(font=dict(family="Arial",size=14),height=490,margin=dict(t=75,b=100),legend=dict(orientation="h",y=-0.23))
    fig.update_xaxes(automargin=True); fig.update_yaxes(automargin=True)
    display({"application/vnd.plotly.v1+json": json.loads(fig.to_json()), "text/plain": fig.layout.title.text}, raw=True)
print("Verified checksum-listed files:", AUDIT["checksum_files_verified"])
print("Recalculated scores:", AUDIT["independently_recalculated_scores"])
print("No model fits, cloud operations, or Kaggle submissions.")
# Out:
# Verified checksum-listed files: 158
# Recalculated scores: {'control_shared': 0.5692312343124653, 'global_context_ablation': 0.5616706362937891, 'repeat_context': 0.5584510290237252}
# No model fits, cloud operations, or Kaggle submissions.

# %% [markdown]
# ### Overall comparison

# %%
names=["Control · 134", "Repeat context · 146", "Global context · 146"]
keys=["control_shared","repeat_context","global_context_ablation"]
f=go.Figure(go.Bar(x=names,y=[RESULT["arms"][k]["weighted_recall_at_20"] for k in keys],text=[f'{RESULT["arms"][k]["weighted_recall_at_20"]:.6f}' for k in keys],textposition="outside"))
f.update_layout(title="01 · Round 06 / matched weighted Recall@20",yaxis_title="Internal fitting-cohort score")
emit(f)
# Out:
# 01 · Round 06 / matched weighted Recall@20

# %% [markdown]
# ### Uncertainty, without overstating the result

# %%
keys=["repeat_context_minus_control_shared","global_context_ablation_minus_control_shared"]
v=[RESULT["comparisons"][k] for k in keys]
f=go.Figure(go.Scatter(x=[a["gain"] for a in v],y=["Repeat context","Global context"],mode="markers",error_x=dict(type="data",symmetric=False,array=[a["descriptive_95_interval"][1]-a["gain"] for a in v],arrayminus=[a["gain"]-a["descriptive_95_interval"][0] for a in v])))
f.add_vline(x=0,line_dash="dash")
f.update_layout(title="02 · Paired gain / descriptive 95% intervals",xaxis_title="Difference from saved control")
emit(f)
# Out:
# 02 · Paired gain / descriptive 95% intervals

# %% [markdown]
# ### Chronological consistency

# %%
f=go.Figure()
for arm,label in [("repeat_context","Repeat context"),("global_context_ablation","Global context")]:
    f.add_bar(name=label,x=["Fold 0","Fold 1"],y=RESULT["comparisons"][arm+"_minus_control_shared"]["fold_gains"])
f.update_layout(title="03 · Neither addition improved either fold",barmode="group",yaxis_title="Gain against matched control")
emit(f)
# Out:
# 03 · Neither addition improved either fold

# %% [markdown]
# ### Action-specific performance

# %%
f=go.Figure()
for arm,label in [("control_shared","Control"),("repeat_context","Repeat context"),("global_context_ablation","Global context")]:
    f.add_bar(name=label,x=["Clicks","Carts","Orders"],y=[RESULT["arms"][arm]["recall"][k] for k in ["clicks","carts","orders"]])
f.update_layout(title="04 · Recall by objective",barmode="group",yaxis_title="Recall@20")
emit(f)
# Out:
# 04 · Recall by objective

# %% [markdown]
# ### Exact hits explain the difference

# %%
f=go.Figure()
for arm,label in [("repeat_context","Repeat context"),("global_context_ablation","Global context")]:
    f.add_bar(name=label,x=["Clicks","Carts","Orders"],y=[RESULT["comparisons"][arm+"_minus_control_shared"]["net_extra_hits"][k] for k in ["clicks","carts","orders"]])
f.update_layout(title="05 · Lost target hits, relative to the control",barmode="group",yaxis_title="Net hits")
emit(f)
# Out:
# 05 · Lost target hits, relative to the control

# %% [markdown]
# ### Candidate availability versus ranking

# %%
p=COVERAGE["pooled"]
f=go.Figure(go.Waterfall(x=["Achieved control","Within-pool opportunity","Missing-candidate gap","Ideal reference"],measure=["absolute","relative","relative","total"],y=[p["achieved_control"]["weighted_recall_at_20"],p["weighted_within_candidate_ranking_gap"],p["weighted_missing_candidate_gap"],0]))
f.update_layout(title="06 · Arithmetic gap decomposition — not causal attribution",yaxis_title="Weighted score units")
emit(f)
# Out:
# 06 · Arithmetic gap decomposition — not causal attribution

# %% [markdown]
# ### Training support by repeat/discovery status

# %%
# Fold 1 only: do not double-count the overlapping expanding training folds.
r=CONTEXT[1]
f=go.Figure()
for group in ["repeat","discovery"]:
    f.add_bar(name=group.title(),x=["Clicks","Carts","Orders"],y=[r["strata"][group]["censored_positive_counts"][k] for k in ["clicks","carts","orders"]])
f.update_layout(title="07 · Censored training positives / later training fold",barmode="stack",yaxis_title="Candidate-positive items")
emit(f)
# Out:
# 07 · Censored training positives / later training fold

# %% [markdown]
# ### How much did the two transformations differ?

# %%
f=go.Figure()
for r in CONTEXT:
    f.add_bar(name="Training fold "+str(r["fold"]),x=list(range(1,13)),y=r["mean_abs_primary_minus_global"])
f.update_layout(title="08 · Conditioning changed these affinity transforms only slightly",barmode="group",xaxis_title="Added feature number",yaxis_title="Mean absolute primary-minus-global value")
emit(f)
# Out:
# 08 · Conditioning changed these affinity transforms only slightly

# %% [markdown]
# ## Decision / Round 07
# Build 12 historical-session evidence features and a last-anchor information-removal comparison. Use an ID-selected 256-query subset of the earliest fold's training sessions. Audit historical support and candidate coverage before any new ranker fitting.
#
# **Limitations:** The return ZIP contains statistics and receipts, not complete native model, candidate or historical-source binaries. All scores and intervals were reproduced from integer hit statistics. The candidate-oracle arithmetic was checked, but candidate membership was not independently replayed. The returned Round 06 saved-results notebook had zero executed cells; its generated HTML and nine plot files existed. This notebook is a fresh executed review.
