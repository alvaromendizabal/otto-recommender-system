# %% [markdown]
# # OTTO · Round 01 — Saved results and kernel check
#
# **No training is run by this notebook.** The 48-feature experiment is already complete. This notebook reads the verified saved outputs, prints the actual interpreter, and sends seven small Plotly JSON displays explicitly. It never imports the experiment launcher or uses an automatic HTML renderer.
#
# Select **OTTO - Notebook**, then run the first code cell alone. After `KERNEL_READY` receives an execution number and the kernel is Idle, run the remaining cells. Do not rerun the earlier training notebook from its backup.
#
# The named kernel is a registration for an already installed interpreter, not proof of a newly isolated environment. The actual notebook and ML paths are printed below.

# %%
from pathlib import Path
import os, sys
ROOT = Path(os.environ.get('OTTO_NOTEBOOK_REVIEW_ROOT', str(Path.home() / 'otto_feature_round01')))
sys.path.insert(0, str(ROOT))
from otto_notebook_support import SavedReview
review = SavedReview(ROOT)
review.start()
# Out:
# KERNEL_READY
# Notebook Python: /opt/conda/bin/python
# ML Python (unchanged; not started by this notebook): /home/sagemaker-user/otto-recommender-system/.venv/bin/python
# Mode: saved results only. No run_stage calls, model fits, or data downloads.

# %% [markdown]
# ## Completed measurements
# These are fitting-only comparisons on 512 validation sessions, not a new Kaggle score.

# %%
review.summary()
# Out:
# 134-feature saved control    0.484737  hits=[219, 65, 48]
# +24 support features         0.480984  hits=[223, 66, 47]
# +24 timing features          0.494230  hits=[224, 66, 49]
# +48 combined features        0.482541  hits=[221, 67, 47]
# Timing gain: +0.009493
# Descriptive interval: [-0.0037692462855691074, 0.02656019737277989]
# Both forward-fold gains: [0.010909090909090924, 0.006436056203858009]
# Primary combined arm failed its gate. Timing-only remains a replication hypothesis.
# Fitting-only result; not a Kaggle score. No automatic feature retention.

# %% [markdown]
# ## Matched scores

# %%
review.show_chart(1)
# Out:
# Matched fitting-only score — NOT Kaggle leaderboard performance. Interactive fallback: download outputs/round01_report.html.
# CHART_1_PAYLOAD_SENT — Python display call returned.

# %% [markdown]
# ## Added feature value and descriptive uncertainty

# %%
review.show_chart(2)
# Out:
# Added feature value and descriptive paired uncertainty. Interactive fallback: download outputs/round01_report.html.
# CHART_2_PAYLOAD_SENT — Python display call returned.

# %% [markdown]
# ## Chronological stability

# %%
review.show_chart(3)
# Out:
# Does the gain survive both chronological folds?. Interactive fallback: download outputs/round01_report.html.
# CHART_3_PAYLOAD_SENT — Python display call returned.

# %% [markdown]
# ## Click, cart and order contributions

# %%
review.show_chart(4)
# Out:
# Which objective moves? Full target denominators retained. Interactive fallback: download outputs/round01_report.html.
# CHART_4_PAYLOAD_SENT — Python display call returned.

# %% [markdown]
# ## Matched group ablations

# %%
review.show_chart(5)
# Out:
# Matched group ablations. Interactive fallback: download outputs/round01_report.html.
# CHART_5_PAYLOAD_SENT — Python display call returned.

# %% [markdown]
# ## Training-only feature support

# %%
review.show_chart(6)
# Out:
# Where does each feature have nonzero evidence? Training rows only. Interactive fallback: download outputs/round01_report.html.
# CHART_6_PAYLOAD_SENT — Python display call returned.

# %% [markdown]
# ## Overlap with the existing representation

# %%
review.show_chart(7)
# Out:
# Support versus overlap with the existing representation. Interactive fallback: download outputs/round01_report.html.
# CHART_7_PAYLOAD_SENT — Python display call returned.

# %% [markdown]
# ## Finish this bounded review
#
# The final marker records completion of Python code, not independent verification of browser rendering. After it appears, save this notebook and download `otto_notebook_check.zip` from the package folder. The existing `outputs/round01_report.html` remains the self-contained interactive fallback.
#
# The combined/support variants failed this pilot. The 24 timing features remain an uncertain replication hypothesis. No more model fits start here.

# %%
review.finish()
# Out:
# NOTEBOOK_REVIEW_COMPLETE
# No model training, package installation, or feature construction was performed.
# Browser rendering is separate; this marker proves that the final Python cell ran.
# RETURN_FILE: /home/sagemaker-user/otto_feature_round01/otto_notebook_check.zip
