# %% [markdown]
# # Round 10 · Saved evidence dashboard
#
# **Run All is appropriate here after reporting succeeds.** These cells display saved Plotly figures only. Save notebook outputs before the final terminal bundle command.

# %%
from pathlib import Path
import importlib.util, json
ROOT = Path.home() / 'otto_feature_round10'
spec = importlib.util.spec_from_file_location('otto_round10_launcher', ROOT / 'launch.py')
launcher = importlib.util.module_from_spec(spec)
spec.loader.exec_module(launcher)
def stage(name):
    return launcher.run_stage(name)
def require(path, status):
    row = json.loads(Path(path).read_text())
    if row.get('status') != status:
        raise RuntimeError('Expected ' + status + '; stop and bundle evidence.')
    print(status)
    return row
print('KERNEL_READY')
import hashlib
import plotly.io as pio
from IPython.display import display
receipt = require(ROOT/'outputs/report_receipt.json','ROUND10_REPORT_READY')
assert hashlib.sha256((ROOT/'outputs/result.json').read_bytes()).hexdigest() == receipt['result_sha256']
# Out:
# KERNEL_READY
# ROUND10_REPORT_READY

# %% [markdown]
# ## 1 · Matched weighted Recall@20

# %%
path = ROOT/'outputs/plots/01.json'
if hashlib.sha256(path.read_bytes()).hexdigest() != receipt['plot_hashes'][path.name]:
    raise ValueError('Saved chart checksum changed')
fig = pio.from_json(path.read_text())
display({'application/vnd.plotly.v1+json':json.loads(pio.to_json(fig))}, raw=True)

# %% [markdown]
# ## 2 · Descriptive paired intervals

# %%
path = ROOT/'outputs/plots/02.json'
if hashlib.sha256(path.read_bytes()).hexdigest() != receipt['plot_hashes'][path.name]:
    raise ValueError('Saved chart checksum changed')
fig = pio.from_json(path.read_text())
display({'application/vnd.plotly.v1+json':json.loads(pio.to_json(fig))}, raw=True)

# %% [markdown]
# ## 3 · Chronological fold stability

# %%
path = ROOT/'outputs/plots/03.json'
if hashlib.sha256(path.read_bytes()).hexdigest() != receipt['plot_hashes'][path.name]:
    raise ValueError('Saved chart checksum changed')
fig = pio.from_json(path.read_text())
display({'application/vnd.plotly.v1+json':json.loads(pio.to_json(fig))}, raw=True)

# %% [markdown]
# ## 4 · Click/cart/order recall

# %%
path = ROOT/'outputs/plots/04.json'
if hashlib.sha256(path.read_bytes()).hexdigest() != receipt['plot_hashes'][path.name]:
    raise ValueError('Saved chart checksum changed')
fig = pio.from_json(path.read_text())
display({'application/vnd.plotly.v1+json':json.loads(pio.to_json(fig))}, raw=True)

# %% [markdown]
# ## 5 · Exact hits explaining gains

# %%
path = ROOT/'outputs/plots/05.json'
if hashlib.sha256(path.read_bytes()).hexdigest() != receipt['plot_hashes'][path.name]:
    raise ValueError('Saved chart checksum changed')
fig = pio.from_json(path.read_text())
display({'application/vnd.plotly.v1+json':json.loads(pio.to_json(fig))}, raw=True)

# %% [markdown]
# ## 6 · Primary versus unordered representation

# %%
path = ROOT/'outputs/plots/06.json'
if hashlib.sha256(path.read_bytes()).hexdigest() != receipt['plot_hashes'][path.name]:
    raise ValueError('Saved chart checksum changed')
fig = pio.from_json(path.read_text())
display({'application/vnd.plotly.v1+json':json.loads(pio.to_json(fig))}, raw=True)

# %% [markdown]
# ## 7 · Training-only support and redundancy

# %%
path = ROOT/'outputs/plots/07.json'
if hashlib.sha256(path.read_bytes()).hexdigest() != receipt['plot_hashes'][path.name]:
    raise ValueError('Saved chart checksum changed')
fig = pio.from_json(path.read_text())
display({'application/vnd.plotly.v1+json':json.loads(pio.to_json(fig))}, raw=True)

# %% [markdown]
# ## 8 · Candidate ceilings versus achieved ranking

# %%
path = ROOT/'outputs/plots/08.json'
if hashlib.sha256(path.read_bytes()).hexdigest() != receipt['plot_hashes'][path.name]:
    raise ValueError('Saved chart checksum changed')
fig = pio.from_json(path.read_text())
display({'application/vnd.plotly.v1+json':json.loads(pio.to_json(fig))}, raw=True)

# %% [markdown]
# ## 9 · Training-positive feature support

# %%
path = ROOT/'outputs/plots/09.json'
if hashlib.sha256(path.read_bytes()).hexdigest() != receipt['plot_hashes'][path.name]:
    raise ValueError('Saved chart checksum changed')
fig = pio.from_json(path.read_text())
display({'application/vnd.plotly.v1+json':json.loads(pio.to_json(fig))}, raw=True)

# %%
print('ROUND10_RESULTS_DISPLAYED: save all notebooks, then run launch.py bundle in a terminal')
# Out:
# ROUND10_RESULTS_DISPLAYED: save all notebooks, then run launch.py bundle in a terminal
