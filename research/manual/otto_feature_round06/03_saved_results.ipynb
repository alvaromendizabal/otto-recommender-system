# %% [markdown]
# # Round06 · Saved research results
#
# Run All is safe **after the report stage succeeded**: this notebook only displays saved Plotly JSON and bundles evidence. It does not fit models or rebuild features. Nine charts are emitted explicitly to the Jupyter frontend. After completion, save all notebooks and run the bundle command again to include their latest saved bytes.

# %%
from pathlib import Path
import importlib.util, sys
ROOT = Path.home()/"otto_feature_round06"
spec = importlib.util.spec_from_file_location("otto_round06_saved_view", ROOT/"notebook_view.py")
assert spec is not None and spec.loader is not None
view = importlib.util.module_from_spec(spec)
sys.modules[spec.name] = view
spec.loader.exec_module(view)
result = view.start()
# Out:
# KERNEL_READY — saved results only, no training. Notebook Python: /opt/conda/bin/python
# **Decision:** STOP_THIS_CONFIGURATION_NO_GAIN
#
# **Repeat-conditioned context primary gain versus matched control:** -0.010780
#
# Reused fitting-cohort exploratory feature screen. Not a Kaggle score; no feature promotion.

# %% [markdown]
# ## Matched overall metric

# %%
view.show_chart(1)
# Out:
# Round 06 chart 1 (interactive Plotly)
# CHART_1_PAYLOAD_SENT — Python display returned.

# %% [markdown]
# ## Descriptive uncertainty

# %%
view.show_chart(2)
# Out:
# Round 06 chart 2 (interactive Plotly)
# CHART_2_PAYLOAD_SENT — Python display returned.

# %% [markdown]
# ## Earlier and later fold gains

# %%
view.show_chart(3)
# Out:
# Round 06 chart 3 (interactive Plotly)
# CHART_3_PAYLOAD_SENT — Python display returned.

# %% [markdown]
# ## Action-specific recall

# %%
view.show_chart(4)
# Out:
# Round 06 chart 4 (interactive Plotly)
# CHART_4_PAYLOAD_SENT — Python display returned.

# %% [markdown]
# ## Exact-hit contributions

# %%
view.show_chart(5)
# Out:
# Round 06 chart 5 (interactive Plotly)
# CHART_5_PAYLOAD_SENT — Python display returned.

# %% [markdown]
# ## Effect of repeat conditioning

# %%
view.show_chart(6)
# Out:
# Round 06 chart 6 (interactive Plotly)
# CHART_6_PAYLOAD_SENT — Python display returned.

# %% [markdown]
# ## Training-only redundancy

# %%
view.show_chart(7)
# Out:
# Round 06 chart 7 (interactive Plotly)
# CHART_7_PAYLOAD_SENT — Python display returned.

# %% [markdown]
# ## Candidate coverage versus ranking

# %%
view.show_chart(8)
# Out:
# Round 06 chart 8 (interactive Plotly)
# CHART_8_PAYLOAD_SENT — Python display returned.

# %% [markdown]
# ## Training-positive signal support

# %%
view.show_chart(9)
# Out:
# Round 06 chart 9 (interactive Plotly)
# CHART_9_PAYLOAD_SENT — Python display returned.

# %% [markdown]
# ## Save and return
# Save with Ctrl+S, then re-run the terminal bundle command in START_HERE.md. Download `otto_round06_return.zip`. Stop the **application**, not just the kernel; do not delete the space.

# %%
view.finish()
# Out:
# ROUND06_NOTEBOOK_REVIEW_COMPLETE
# RETURN_FILE: /home/sagemaker-user/otto_feature_round06/otto_round06_return.zip
# CompletedProcess(args=['/opt/conda/bin/python', '-u', '/home/sagemaker-user/otto_feature_round06/launch.py', 'bundle'], returncode=0)
