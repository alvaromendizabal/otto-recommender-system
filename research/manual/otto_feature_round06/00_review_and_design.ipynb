# %% [markdown]
# # OTTO · Round05 result review / Round06 design
#
# **Keep the 134-feature control. Neither Round05 addition earned retention.**
#
# This notebook displays the actual, independently audited Round05 return. It performs no model fitting. Six Plotly figures explain the result. The proposed Round06 adds repeat-conditioned graph context, not another demand percentile family.
#
# All metrics below are fitting-cohort diagnostics. No leaderboard equivalence, promotion, or guaranteed score improvement is implied.

# %%
from pathlib import Path
import hashlib, json
from IPython.display import display, Markdown
ROOT = Path.cwd() if (Path.cwd()/"review/manifest.json").is_file() else Path.home()/"otto_feature_round06"
plots = json.loads((ROOT/"review/manifest.json").read_text())
def show_review(number):
    path = ROOT/"review"/f"{number:02d}.json"
    assert hashlib.sha256(path.read_bytes()).hexdigest() == plots[path.name], "Review checksum mismatch"
    display({"application/vnd.plotly.v1+json": json.loads(path.read_text()), "text/plain": f"Round05 audited chart {number}"}, raw=True)
    print(f"ROUND05_REVIEW_CHART_{number}_SENT")
audit = json.loads((ROOT/"evidence/ROUND05_AUDIT.json").read_text())
print("KERNEL_READY — saved evidence only; verified files:", audit["verified_manifest_files"])
display(Markdown("**Decision:** Freeze the negative Round05 result; do not rerun its completed index or models."))
# Out:
# KERNEL_READY — saved evidence only; verified files: 66
# **Decision:** Freeze the negative Round05 result; do not rerun its completed index or models.

# %% [markdown]
# ## Overall outcome

# %%
show_review(1)
# Out:
# Round05 audited chart 1
# ROUND05_REVIEW_CHART_1_SENT

# %% [markdown]
# ## Uncertainty and repeated-cohort limits

# %%
show_review(2)
# Out:
# Round05 audited chart 2
# ROUND05_REVIEW_CHART_2_SENT

# %% [markdown]
# ## Chronological stability

# %%
show_review(3)
# Out:
# Round05 audited chart 3
# ROUND05_REVIEW_CHART_3_SENT

# %% [markdown]
# ## Clicks, carts and orders

# %%
show_review(4)
# Out:
# Round05 audited chart 4
# ROUND05_REVIEW_CHART_4_SENT

# %% [markdown]
# ## Exact-hit attribution

# %%
show_review(5)
# Out:
# Round05 audited chart 5
# ROUND05_REVIEW_CHART_5_SENT

# %% [markdown]
# ## Training support

# %%
show_review(6)
# Out:
# Round05 audited chart 6
# ROUND05_REVIEW_CHART_6_SENT

# %% [markdown]
# ## Round06: repeated products versus unseen alternatives
#
# For six existing graph-affinity signals, compute rank/share within a candidate's complete-prefix seen/unseen group. Compare with the same rank/share computed globally over 400 candidates. Both arms add 12 columns to the saved 134. Existing repetition and graph scores are not claimed as new; the group-conditioned representation is the hypothesis.
#
# **No new index or raw-data scan.** Use `01_build_context_features.ipynb` for tests/features, then `02_run_context_comparison.ipynb` for the matched screen, one cell at a time. `RESEARCH_PLAN.md` contains primary sources, exact formulas and the next research queue.

# %%
print("ROUND05_REVIEW_COMPLETE — next: 01_build_context_features.ipynb")
# Out:
# ROUND05_REVIEW_COMPLETE — next: 01_build_context_features.ipynb
