# %% [markdown]
# # OTTO · Round 03 — saved results
#
# **No training or feature generation in this notebook.** All values come from the returned experiment and audited integer statistics.

# %%
from pathlib import Path
import sys
ROOT = next((p for p in [Path.cwd(), *Path.cwd().parents]
             if (p / "launch.py").is_file() and (p / "protocol.json").is_file()),
            Path.home() / "otto_feature_round03")
if not (ROOT / "launch.py").is_file():
    raise RuntimeError("Open this notebook from the extracted otto_feature_round03 folder")
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))
import notebook_view as view
result = view.start()
# Out:
# KERNEL_READY — saved results only, no training. Notebook Python: /opt/conda/bin/python
# **Decision:** STOP_THIS_CONFIGURATION_NO_GAIN
#
# **Recent-mass primary gain versus matched control:** -0.005007
#
# Reused fitting-cohort exploratory feature screen. Not a Kaggle score; no feature promotion.

# %% [markdown]
# ## Matched pooled scores

# %%
view.show_chart(1)
# Out:
# Round 03 chart 1 (interactive Plotly)
# CHART_1_PAYLOAD_SENT — Python display returned.

# %% [markdown]
# ## Paired uncertainty

# %%
view.show_chart(2)
# Out:
# Round 03 chart 2 (interactive Plotly)
# CHART_2_PAYLOAD_SENT — Python display returned.

# %% [markdown]
# ## Temporal-fold stability

# %%
view.show_chart(3)
# Out:
# Round 03 chart 3 (interactive Plotly)
# CHART_3_PAYLOAD_SENT — Python display returned.

# %% [markdown]
# ## Click/cart/order results

# %%
view.show_chart(4)
# Out:
# Round 03 chart 4 (interactive Plotly)
# CHART_4_PAYLOAD_SENT — Python display returned.

# %% [markdown]
# ## Extra-hit contributions

# %%
view.show_chart(5)
# Out:
# Round 03 chart 5 (interactive Plotly)
# CHART_5_PAYLOAD_SENT — Python display returned.

# %% [markdown]
# ## Training-only evidence availability

# %%
view.show_chart(6)
# Out:
# Round 03 chart 6 (interactive Plotly)
# CHART_6_PAYLOAD_SENT — Python display returned.

# %% [markdown]
# ## Training-only redundancy

# %%
view.show_chart(7)
# Out:
# Round 03 chart 7 (interactive Plotly)
# CHART_7_PAYLOAD_SENT — Python display returned.

# %% [markdown]
# ## Finished
# Save this notebook, run `launch.py bundle` once to capture its saved bytes, download `otto_round03_return.zip`, and stop unused SageMaker compute.

# %%
view.finish()
# Out:
# ROUND03_NOTEBOOK_REVIEW_COMPLETE
# RETURN_FILE: /home/sagemaker-user/otto_feature_round03/otto_round03_return.zip
# '/home/sagemaker-user/otto_feature_round03/otto_round03_return.zip'
