# %% [markdown]
# # OTTO | Recorded feature results
#
# Public implementation and internal results. Supplied unexecuted; no outputs are fabricated. Run with the existing Plotly environment, save with Ctrl+S, reopen to check the plots. GitHub does not execute interactive JavaScript in its notebook preview.

# %%
from pathlib import Path
import json
import plotly.graph_objects as go
import plotly.io as pio
pio.renderers.default = "notebook+plotly_mimetype"
results = json.loads('{"evaluation": "Exploratory internal fitting folds; NOT leaderboard scores.", "limitations": "Compare only within a matched round. Reused cohorts and adaptive hypothesis selection limit inference.", "provenance": "Recorded owner-run AWS results; aggregate integer arithmetic checked, no model replay during publication.", "rounds": [{"round": 1, "arms": [{"arm": "control_shared", "weighted_recall_at_20": 0.48473688289545064, "hits": [219, 65, 48], "denominators": [495, 153, 92]}, {"arm": "plus_both", "weighted_recall_at_20": 0.48254075279650727, "hits": [221, 67, 47], "denominators": [495, 153, 92]}, {"arm": "plus_support", "weighted_recall_at_20": 0.4809840088868222, "hits": [223, 66, 47], "denominators": [495, 153, 92]}, {"arm": "plus_timing", "weighted_recall_at_20": 0.49422950734971194, "hits": [224, 66, 49], "denominators": [495, 153, 92]}], "source_sha256": "45d0edc2d7c8150041b7beb15c8f0747fb30b0d8b83c469a3e5118f5a545ffc6"}, {"round": 2, "arms": [{"arm": "control_shared", "weighted_recall_at_20": 0.5692312343124653, "hits": [989, 227, 217], "denominators": [1979, 574, 325]}, {"arm": "plus_timing", "weighted_recall_at_20": 0.5664249996173978, "hits": [970, 227, 216], "denominators": [1979, 574, 325]}], "source_sha256": "0199ef13727d4224dfbbc48073f4b40f865a9f40bb429d5022c3e53828ada741"}, {"round": 3, "arms": [{"arm": "control_shared", "weighted_recall_at_20": 0.5692312343124653, "hits": [989, 227, 217], "denominators": [1979, 574, 325]}, {"arm": "mass_missing_aware", "weighted_recall_at_20": 0.5642245488646602, "hits": [974, 233, 213], "denominators": [1979, 574, 325]}, {"arm": "mass_zero_ablation", "weighted_recall_at_20": 0.5570758268709686, "hits": [978, 226, 211], "denominators": [1979, 574, 325]}], "source_sha256": "1fc3a19abf34b421f14d0ac2738e3e194b325a345648597eaa2c3515cd7bed75"}, {"round": 4, "arms": [{"arm": "control_shared", "weighted_recall_at_20": 0.5692312343124653, "hits": [989, 227, 217], "denominators": [1979, 574, 325]}, {"arm": "demand_rolling", "weighted_recall_at_20": 0.5540236571375481, "hits": [990, 219, 211], "denominators": [1979, 574, 325]}, {"arm": "demand_static_ablation", "weighted_recall_at_20": 0.5528952251115945, "hits": [967, 212, 213], "denominators": [1979, 574, 325]}], "source_sha256": "57b9e47b6db786efbef675631f819e9ae1f9d29efb4b06097d7715bc87fd9234"}, {"round": 5, "arms": [{"arm": "action_pairs", "weighted_recall_at_20": 0.556427143814664, "hits": [970, 222, 212], "denominators": [1979, 574, 325]}, {"arm": "collapsed_action_ablation", "weighted_recall_at_20": 0.5628419674337174, "hits": [977, 223, 215], "denominators": [1979, 574, 325]}, {"arm": "control_shared", "weighted_recall_at_20": 0.5692312343124653, "hits": [989, 227, 217], "denominators": [1979, 574, 325]}], "source_sha256": "6300b288abf57956fe0f1016eb77fee8271aefc6daa750ccfdda128483753eca"}, {"round": 6, "arms": [{"arm": "control_shared", "weighted_recall_at_20": 0.5692312343124653, "hits": [989, 227, 217], "denominators": [1979, 574, 325]}, {"arm": "global_context_ablation", "weighted_recall_at_20": 0.5616706362937891, "hits": [969, 218, 216], "denominators": [1979, 574, 325]}, {"arm": "repeat_context", "weighted_recall_at_20": 0.5584510290237252, "hits": [957, 213, 216], "denominators": [1979, 574, 325]}], "source_sha256": "11045ef1872740aa84819ecc407a328970ceea9205d7bd1025daf13691451d33"}, {"round": 8, "arms": [{"arm": "control_shared", "weighted_recall_at_20": 0.5692312343124653, "hits": [989, 227, 217], "denominators": [1979, 574, 325]}, {"arm": "equal_weight_ablation", "weighted_recall_at_20": 0.5658773777030842, "hits": [964, 223, 217], "denominators": [1979, 574, 325]}, {"arm": "rarity_neighbors", "weighted_recall_at_20": 0.5625975289453764, "hits": [977, 219, 216], "denominators": [1979, 574, 325]}], "source_sha256": "af6aed9fa26245fe8d42eba981c255ad478fa4daca465acc6655c6f82fc77461"}, {"round": 9, "arms": [{"arm": "control_shared", "weighted_recall_at_20": 0.5692312343124653, "hits": [989, 227, 217], "denominators": [1979, 574, 325]}, {"arm": "forward_continuation", "weighted_recall_at_20": 0.5680017411445208, "hits": [964, 220, 219], "denominators": [1979, 574, 325]}, {"arm": "unsigned_window_ablation", "weighted_recall_at_20": 0.5676797187948669, "hits": [999, 216, 219], "denominators": [1979, 574, 325]}], "source_sha256": "202f222a04a2c733728b7db67c6620a48ca3f739ad082ce8caec4690e06e0b0f"}, {"round": 10, "arms": [{"arm": "control_shared", "weighted_recall_at_20": 0.5692312343124653, "hits": [989, 227, 217], "denominators": [1979, 574, 325]}, {"arm": "ordered_funnel", "weighted_recall_at_20": 0.5672672598602669, "hits": [986, 220, 218], "denominators": [1979, 574, 325]}, {"arm": "unordered_funnel_ablation", "weighted_recall_at_20": 0.5670569232096487, "hits": [977, 224, 217], "denominators": [1979, 574, 325]}], "source_sha256": "cc2e4725908a7e3dc39d65e95c801efaf817ffffc5debc9701b35feff586fa6b"}], "unpublished_metric_records": []}')
out = Path("rendered_figures"); out.mkdir(exist_ok=True)
print(results["evaluation"])

# %%
for item in results["rounds"]:
    fig = go.Figure(go.Bar(x=[a["arm"] for a in item["arms"]], y=[a["weighted_recall_at_20"] for a in item["arms"]]))
    fig.update_layout(title=f"Round {item['round']}: matched internal scores", xaxis_title="Representation", yaxis_title="Weighted Recall@20", height=520)
    fig.show()
    fig.write_html(out / f"round{item['round']:02d}.html", include_plotlyjs=True)
    fig.write_json(out / f"round{item['round']:02d}.json")
print("Save this notebook; close and reopen it to verify the saved inline plots.")
